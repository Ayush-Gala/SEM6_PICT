# %%
import pandas as pd
import numpy as np
df = pd.read_csv("student_performance_2.csv")
df
# Out:
#       Student ID  Gender  Age School  Math Score  Reading Score  \
# 0              1    Male   21      A        89.0           47.0
# 1              2  Female   19      E        71.0           76.0
# 2              3  Female   18      A         NaN          100.0
# 3              4  Female   20      C         NaN           76.0
# 4              5  Female   20      D        58.0           56.0
# ...          ...     ...  ...    ...         ...            ...
# 6995        6996  Female   17      A        87.0           54.0
# 6996        6997  Female   18      D        69.0           98.0
# 6997        6998  Female   20      C        89.0           74.0
# 6998        6999  Female   20      A        57.0           99.0
# 6999        7000    Male   18      D        83.0           62.0
#
#       Writing Score Class Performance
# 0              30.0                 F
# 1              53.0                 D
# 2              77.0                 C
# 3              49.0                 F
# 4              67.0                 D
# ...             ...               ...
# 6995           40.0                 D
# 6996          129.0                 C
# 6997           67.0                 C
# 6998           81.0                 C
# 6999            NaN                 C
#
# [7000 rows x 8 columns]

# %%
#checking for NaN values
df.describe()
# Out:
#         Student ID          Age   Math Score  Reading Score  Writing Score
# count  7000.000000  7000.000000  6659.000000    6692.000000    6684.000000
# mean   3500.500000    19.000143    65.573510      65.414824      65.740126
# std    2020.870275     1.423930    21.414478      21.663954      21.254082
# min       1.000000    17.000000    30.000000      30.000000      30.000000
# 25%    1750.750000    18.000000    48.000000      47.000000      48.000000
# 50%    3500.500000    19.000000    65.000000      65.000000      65.000000
# 75%    5250.250000    20.000000    83.000000      83.000000      83.000000
# max    7000.000000    21.000000   150.000000     150.000000     150.000000

# %%
df.isna().sum()
# Out:
# Student ID             0
# Gender                 0
# Age                    0
# School                 0
# Math Score           341
# Reading Score        308
# Writing Score        316
# Class Performance      0
# dtype: int64

# %%
#detecting the outliers in the data set

df.plot.scatter(y="Reading Score", x="Math Score", s=4, figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Math Score', ylabel='Reading Score'>

# %%
df.plot.scatter(y="Reading Score", x="Writing Score", s=4, figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='Writing Score', ylabel='Reading Score'>

# %%
#removing the outliers from the dataset
